# %% [markdown]
# <a href="https://colab.research.google.com/github/HimanshuRajput-0/Python/blob/main/OOP_in_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OOP Introduction :

# %% [markdown]
# Object oriented programming is a widely used concept for writting applications.

# %% [markdown]
# Have to learn how to create classes, instantiate obejcts, how to define methods, pass arguments and to add arguments to the class.

# %% [markdown]
# OOP organizes code around classes(blueprints) and objects(instances of those blueprints)

# %% [markdown]
# A class is defined with a class keyword and initialize attributes inside __ init __ (self)

# %% [markdown]
# Instance methods operate data via self and are called with dot notation: my_object.method()

# %% [markdown]
# Four Pillars of OOP :
#
#
# 1.   Encapsulation : Bundling data and methods together, controlling access with the naming conventions.
# 2.   List item

# %% [markdown]
# # How to create a class:

# %% [markdown]
# To define a class in python we use the class keyword followed by the class name and the colon:

# %% [markdown]
# # Encapsulation :

# %% [markdown]
# It is a fundamental object orirented principle. It protects our class from accidental changes or deletion and promotes codes reusability and maintainability.

# %% [markdown]
# # Questions for more concept clearance:

# %% [markdown]
# Q1 : What do you mean by an Object in Python?

# %% [markdown]
# Ans : In python every thing is an object : numbers, strings, dataframes even functions are object.
